# %%
import sklearn 
import numpy as np
import pandas as pd

# %%
# 1 load data
dataset=pd.read_csv("https://raw.githubusercontent.com/SeakKimhour/dataset/main/AMD_cpubenchmarks.csv")

# %%
# 2. Dimension of dataset

dataset.shape

dataset.describe()
# Out:
#        1-Core Pts  2-Core Pts  4-Core Pts   8-Core Pts  64-Core Pts  \
# count  387.000000  387.000000  387.000000   387.000000   387.000000
# mean    64.754005  122.737209  208.501292   291.446512   416.676486
# std     34.977764   70.802493  150.969639   290.114942   671.203728
# min     13.000000   21.900000   22.700000    23.200000    23.600000
# 25%     38.100000   71.050000   91.900000    93.600000    93.900000
# 50%     55.800000  106.000000  179.000000   182.000000   184.000000
# 75%     75.350000  145.500000  253.500000   371.500000   375.500000
# max    163.000000  321.000000  622.000000  1209.000000  5296.000000
#
#             Samples  Age (months)  Current Price (USD)
# count  3.870000e+02    387.000000            47.000000
# mean   2.595449e+04     78.795866           358.000000
# std    9.504055e+04     31.367737           406.067782
# min    1.000000e+00      0.000000            20.000000
# 25%    9.305000e+02     57.500000            92.500000
# 50%    2.900000e+03     96.000000           233.000000
# 75%    1.100000e+04    100.000000           394.500000
# max    1.100000e+06    158.000000          2100.000000

# %%
# 3. Check the variable (Numberical / Categorial)

numberical_variable = dataset.columns[dataset.dtypes != 'object']
dataset[numberical_variable].head(10)

categorical_variable = dataset.columns[dataset.dtypes =="object"]
print(dataset[categorical_variable])
# Out:
#     Brand             Model  Seller
# 0     AMD    Ryzen TR 3970X     NaN
# 1     AMD    Ryzen TR 3990X     NaN
# 2     AMD    Ryzen TR 3960X    Ebay
# 3     AMD   Ryzen TR 2990WX  Amazon
# 4     AMD   Ryzen TR 2970WX    Ebay
# ..    ...               ...     ...
# 382   AMD     Sempron 2800      NaN
# 383   AMD              C-50     NaN
# 384   AMD  Athlon Neo MV-40     NaN
# 385   AMD          Z-60 APU     NaN
# 386   AMD      Athlon 2650e     NaN
#
# [387 rows x 3 columns]

# %%
# 4 Missing value 

dataset.isnull()
dataset[numberical_variable].isnull().head(5)
dataset[categorical_variable].isnull().head(5)
# Out:
#    Brand  Model  Seller
# 0  False  False    True
# 1  False  False    True
# 2  False  False   False
# 3  False  False   False
# 4  False  False   False

# %%
# 5. Find out the percentanges of missing values 
dataset.isnull().sum()/ len(dataset)
# Out:
# Brand                  0.000000
# Model                  0.000000
# 1-Core Pts             0.000000
# 2-Core Pts             0.000000
# 4-Core Pts             0.000000
# 8-Core Pts             0.000000
# 64-Core Pts            0.000000
# Samples                0.000000
# Age (months)           0.000000
# Current Price (USD)    0.878553
# Seller                 0.878553
# dtype: float64

# %%
# 6. Replace value 
dataset.fillna(1)
# Out:
#     Brand             Model  1-Core Pts  2-Core Pts  4-Core Pts  8-Core Pts  \
# 0     AMD    Ryzen TR 3970X       129.0       258.0       499.0       994.0
# 1     AMD    Ryzen TR 3990X       125.0       250.0       495.0       986.0
# 2     AMD    Ryzen TR 3960X       130.0       260.0       497.0       994.0
# 3     AMD   Ryzen TR 2990WX       108.0       212.0       404.0       782.0
# 4     AMD   Ryzen TR 2970WX       112.0       220.0       421.0       738.0
# ..    ...               ...         ...         ...         ...         ...
# 382   AMD     Sempron 2800         23.3        24.2        24.7        25.5
# 383   AMD              C-50        13.0        23.7        24.8        25.4
# 384   AMD  Athlon Neo MV-40        21.6        21.9        22.7        23.2
# 385   AMD          Z-60 APU        13.1        23.5        25.3        25.4
# 386   AMD      Athlon 2650e        21.2        22.1        22.9        23.6
#
#      64-Core Pts  Samples  Age (months)  Current Price (USD)  Seller
# 0         5296.0     4600            29                  1.0       1
# 1         5093.0     1000            26                  1.0       1
# 2         4134.0     4500            29               1731.0    Ebay
# 3         3980.0     3100            44               2100.0  Amazon
# 4         3243.0     1700            41                916.0    Ebay
# ..           ...      ...           ...                  ...     ...
# 382         25.7      157            98                  1.0       1
# 383         25.4     1600            99                  1.0       1
# 384         24.1      208            93                  1.0       1
# 385         23.7        5            92                  1.0       1
# 386         23.6      146            98                  1.0       1
#
# [387 rows x 11 columns]

# %%
# 7 . Fillup the mission values 
dataset['Age (months)'].replace(29,90).head(50)
# Out:
# 0     90
# 1     26
# 2     90
# 3     44
# 4     41
# 5     17
# 6     90
# 7     44
# 8     17
# 9     56
# 10    22
# 11    33
# 12    12
# 13    41
# 14    56
# 15    17
# 16     1
# 17    11
# 18     0
# 19    13
# 20    21
# 21    23
# 22    33
# 23     2
# 24    33
# 25    15
# 26     2
# 27     2
# 28    15
# 29    14
# 30    15
# 31    48
# 32    22
# 33    13
# 34    27
# 35    55
# 36    25
# 37     0
# 38    17
# 39    62
# 40    25
# 41    11
# 42     0
# 43    62
# 44    48
# 45    15
# 46    22
# 47    62
# 48    33
# 49    33
# Name: Age (months), dtype: int64

# %%
# 8 Create the rows and add it with the original dataset

row_insert = pd.Series(['AND',"Ryzen 6800h", 129, "TR 3090Ti",512, 123, 5129, 400, 3, 2000,"Amazon"], index = ["Brand", "Model", "1-Core Pts", "2-Core Pts", "4-Core Pts", "8-Core Pts", "64-Core Pts", "Samples", "Age (months)", "Current Price (USD)","Seller"])
dataset.append(row_insert, ignore_index= True)
# Out:
#     Brand             Model  1-Core Pts 2-Core Pts  4-Core Pts  8-Core Pts  \
# 0     AMD    Ryzen TR 3970X       129.0      258.0       499.0       994.0
# 1     AMD    Ryzen TR 3990X       125.0      250.0       495.0       986.0
# 2     AMD    Ryzen TR 3960X       130.0      260.0       497.0       994.0
# 3     AMD   Ryzen TR 2990WX       108.0      212.0       404.0       782.0
# 4     AMD   Ryzen TR 2970WX       112.0      220.0       421.0       738.0
# ..    ...               ...         ...        ...         ...         ...
# 383   AMD              C-50        13.0       23.7        24.8        25.4
# 384   AMD  Athlon Neo MV-40        21.6       21.9        22.7        23.2
# 385   AMD          Z-60 APU        13.1       23.5        25.3        25.4
# 386   AMD      Athlon 2650e        21.2       22.1        22.9        23.6
# 387   AND       Ryzen 6800h       129.0  TR 3090Ti       512.0       123.0
#
#      64-Core Pts  Samples  Age (months)  Current Price (USD)  Seller
# 0         5296.0     4600            29                  NaN     NaN
# 1         5093.0     1000            26                  NaN     NaN
# 2         4134.0     4500            29               1731.0    Ebay
# 3         3980.0     3100            44               2100.0  Amazon
# 4         3243.0     1700            41                916.0    Ebay
# ..           ...      ...           ...                  ...     ...
# 383         25.4     1600            99                  NaN     NaN
# 384         24.1      208            93                  NaN     NaN
# 385         23.7        5            92                  NaN     NaN
# 386         23.6      146            98                  NaN     NaN
# 387       5129.0      400             3               2000.0  Amazon
#
# [388 rows x 11 columns]

# %%
#9 Choose exact row from the dataset
dataset.iloc[0] #ilog help us to get specific row based on the index

dataset.iloc[1:5]
dataset[1:17]

datasetValue = dataset.set_index(dataset['Model']) 
datasetValue.loc['Ryzen TR 3960X']
# Out:
# Brand                             AMD
# Model                  Ryzen TR 3960X
# 1-Core Pts                      130.0
# 2-Core Pts                      260.0
# 4-Core Pts                      497.0
# 8-Core Pts                      994.0
# 64-Core Pts                    4134.0
# Samples                          4500
# Age (months)                       29
# Current Price (USD)            1731.0
# Seller                           Ebay
# Name: Ryzen TR 3960X, dtype: object

# %%
#10 Rename the column

dataset.rename(columns={'Model' : "Models"})
# Out:
#     Brand            Models  1-Core Pts  2-Core Pts  4-Core Pts  8-Core Pts  \
# 0     AMD    Ryzen TR 3970X       129.0       258.0       499.0       994.0
# 1     AMD    Ryzen TR 3990X       125.0       250.0       495.0       986.0
# 2     AMD    Ryzen TR 3960X       130.0       260.0       497.0       994.0
# 3     AMD   Ryzen TR 2990WX       108.0       212.0       404.0       782.0
# 4     AMD   Ryzen TR 2970WX       112.0       220.0       421.0       738.0
# ..    ...               ...         ...         ...         ...         ...
# 382   AMD     Sempron 2800         23.3        24.2        24.7        25.5
# 383   AMD              C-50        13.0        23.7        24.8        25.4
# 384   AMD  Athlon Neo MV-40        21.6        21.9        22.7        23.2
# 385   AMD          Z-60 APU        13.1        23.5        25.3        25.4
# 386   AMD      Athlon 2650e        21.2        22.1        22.9        23.6
#
#      64-Core Pts  Samples  Age (months)  Current Price (USD)  Seller
# 0         5296.0     4600            29                  NaN     NaN
# 1         5093.0     1000            26                  NaN     NaN
# 2         4134.0     4500            29               1731.0    Ebay
# 3         3980.0     3100            44               2100.0  Amazon
# 4         3243.0     1700            41                916.0    Ebay
# ..           ...      ...           ...                  ...     ...
# 382         25.7      157            98                  NaN     NaN
# 383         25.4     1600            99                  NaN     NaN
# 384         24.1      208            93                  NaN     NaN
# 385         23.7        5            92                  NaN     NaN
# 386         23.6      146            98                  NaN     NaN
#
# [387 rows x 11 columns]

# %%
## 11. Find the min, max, sum, count
print("Max: Data " , dataset["64-Core Pts"].max())
print("Min:  Data", dataset["64-Core Pts"].min())
print("Count: Data", dataset["64-Core Pts"].count())
print("Total: data: ", dataset["64-Core Pts"].sum())
# Out:
# Max: Data  5296.0
# Min:  Data 23.6
# Count: Data 387
# Total: data:  161253.8

# %%
#12 Delete the row and column
datadeteke=dataset
datadeteke=datadeteke.drop("Model", axis= 1)
print(datadeteke)
datadeteke=datadeteke.drop(dataset.columns[2], axis= 1) #Delete the first column 
print(datadeteke)
datadeteke=datadeteke.drop([1], axis = 0) #Delete row where index = 1
print(datadeteke)
# Out:
#     Brand  1-Core Pts  2-Core Pts  4-Core Pts  8-Core Pts  64-Core Pts  \
# 0     AMD       129.0       258.0       499.0       994.0       5296.0
# 1     AMD       125.0       250.0       495.0       986.0       5093.0
# 2     AMD       130.0       260.0       497.0       994.0       4134.0
# 3     AMD       108.0       212.0       404.0       782.0       3980.0
# 4     AMD       112.0       220.0       421.0       738.0       3243.0
# ..    ...         ...         ...         ...         ...          ...
# 382   AMD        23.3        24.2        24.7        25.5         25.7
# 383   AMD        13.0        23.7        24.8        25.4         25.4
# 384   AMD        21.6        21.9        22.7        23.2         24.1
# 385   AMD        13.1        23.5        25.3        25.4         23.7
# 386   AMD        21.2        22.1        22.9        23.6         23.6
#
#      Samples  Age (months)  Current Price (USD)  Seller
# 0       4600            29                  NaN     NaN
# 1       1000            26                  NaN     NaN
# 2       4500            29               1731.0    Ebay
# 3       3100            44               2100.0  Amazon
# 4       1700            41                916.0    Ebay
# ..       ...           ...                  ...     ...
# 382      157            98                  NaN     NaN
# 383     1600            99                  NaN     NaN
# 384      208            93                  NaN     NaN
# 385        5            92                  NaN     NaN
# 386      146            98                  NaN     NaN
#
# [387 rows x 10 columns]
#     Brand  2-Core Pts  4-Core Pts  8-Core Pts  64-Core Pts  Samples  \
# 0     AMD       258.0       499.0       994.0       5296.0     4600
# 1     AMD       250.0       495.0       986.0       5093.0     1000
# 2     AMD       260.0       497.0       994.0       4134.0     4500
# 3     AMD       212.0       404.0       782.0       3980.0     3100
# 4     AMD       220.0       421.0       738.0       3243.0     1700
# ..    ...         ...         ...         ...          ...      ...
# 382   AMD        24.2        24.7        25.5         25.7      157
# 383   AMD        23.7        24.8        25.4         25.4     1600
# 384   AMD        21.9        22.7        23.2         24.1      208
# 385   AMD        23.5        25.3        25.4         23.7        5
# 386   AMD        22.1        22.9        23.6         23.6      146
#
#      Age (months)  Current Price (USD)  Seller
# 0              29                  NaN     NaN
# 1              26                  NaN     NaN
# 2              29               1731.0    Ebay
# 3              44               2100.0  Amazon
# 4              41                916.0    Ebay
# ..            ...                  ...     ...
# 382            98                  NaN     NaN
# 383            99                  NaN     NaN
# 384            93                  NaN     NaN
# 385            92                  NaN     NaN
# 386            98                  NaN     NaN
#
# [387 rows x 9 columns]
#     Brand  2-Core Pts  4-Core Pts  8-Core Pts  64-Core Pts  Samples  \
# 0     AMD       258.0       499.0       994.0       5296.0     4600
# 2     AMD       260.0       497.0       994.0       4134.0     4500
# 3     AMD       212.0       404.0       782.0       3980.0     3100
# 4     AMD       220.0       421.0       738.0       3243.0     1700
# 5     AMD       321.0       622.0      1209.0       2997.0    60000
# ..    ...         ...         ...         ...          ...      ...
# 382   AMD        24.2        24.7        25.5         25.7      157
# 383   AMD        23.7        24.8        25.4         25.4     1600
# 384   AMD        21.9        22.7        23.2         24.1      208
# 385   AMD        23.5        25.3        25.4         23.7        5
# 386   AMD        22.1        22.9        23.6         23.6      146
#
#      Age (months)  Current Price (USD)  Seller
# 0              29                  NaN     NaN
# 2              29               1731.0    Ebay
# 3              44               2100.0  Amazon
# 4              41                916.0    Ebay
# 5              17                640.0  Amazon
# ..            ...                  ...     ...
# 382            98                  NaN     NaN
# 383            99                  NaN     NaN
# 384            93                  NaN     NaN
# 385            92                  NaN     NaN
